# %% [markdown]
# <a href="https://colab.research.google.com/github/shimiiizu/test/blob/master/Analyze01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # XBRLデータの読み込み

# %%
df1 = pd.read_csv('/PL.csv', header=0, index_col=1, encoding='shift_jis')
df1.head(3)
# Out:
#                                                             Unnamed: 0  ...   NetIncome
# date                                                                    ...
# 2016-06-30 00:00:00  jpcrp030000-asr-001_E00012-000_2017-03-31_01_2...  ...   551000000
# 2016-09-30 00:00:00  jpcrp030000-asr-001_E00012-000_2018-03-31_01_2...  ...  1186000000
# 2016-12-31 00:00:00  jpcrp030000-asr-001_E00012-000_2019-03-31_01_2...  ...  2449000000
#
# [3 rows x 11 columns]

# %% [markdown]
# 四半期毎の売り上げデータを

# %%
df1.loc[:,['SALES_q']]
# Out:
#                          SALES_q
# date
# 2016-06-30 00:00:00  52206000000
# 2016-09-30 00:00:00  57364000000
# 2016-12-31 00:00:00  70405000000
# 2017-03-31 00:00:00  56586000000
# 2017-06-30 00:00:00  56844000000
# 2017-09-30 00:00:00  63614000000
# 2017-12-31 00:00:00  77865000000
# 2018-03-31 00:00:00  56460000000
# 2018-06-30 00:00:00  57957000000
# 2018-09-30 00:00:00  61245000000
# 2018-12-31 00:00:00  78581000000
# 2019-03-31 00:00:00  58368000000

# %%
df_2018 = pd.read_csv('/3653_2018.csv', header=1, index_col=['日付'], encoding='shift_jis')
df_2019 = pd.read_csv('/3653_2019.csv', header=1, index_col=['日付'], encoding='shift_jis')


df_2018.columns
# Out:
# Index(['始値', '高値', '安値', '終値', '出来高', '終値調整値'], dtype='object')

# %%
df_2019.dtypes
# Out:
# 始値       int64
# 高値       int64
# 安値       int64
# 終値       int64
# 出来高      int64
# 終値調整値    int64
# dtype: object

# %%
df_2018.index
# Out:
# Index(['2018-01-04', '2018-01-05', '2018-01-09', '2018-01-10', '2018-01-11',
#        '2018-01-12', '2018-01-15', '2018-01-16', '2018-01-17', '2018-01-18',
#        ...
#        '2018-12-14', '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20',
#        '2018-12-21', '2018-12-25', '2018-12-26', '2018-12-27', '2018-12-28'],
#       dtype='object', name='日付', length=245)

# %% [markdown]
# # インデックスを時間の型に変換

# %%
time = pd.to_datetime(df_2018.index)
time
# Out:
# DatetimeIndex(['2018-01-04', '2018-01-05', '2018-01-09', '2018-01-10',
#                '2018-01-11', '2018-01-12', '2018-01-15', '2018-01-16',
#                '2018-01-17', '2018-01-18',
#                ...
#                '2018-12-14', '2018-12-17', '2018-12-18', '2018-12-19',
#                '2018-12-20', '2018-12-21', '2018-12-25', '2018-12-26',
#                '2018-12-27', '2018-12-28'],
#               dtype='datetime64[ns]', name='日付', length=245, freq=None)

# %%
df_2018.index=time
df_2018
# Out:
#               始値    高値    安値    終値     出来高  終値調整値
# 日付
# 2018-01-04  4705  4730  4700  4705   52400   4705
# 2018-01-05  4710  4740  4700  4735   42400   4735
# 2018-01-09  4790  4920  4765  4905  124900   4905
# 2018-01-10  4905  4915  4840  4840   57300   4840
# 2018-01-11  4845  4875  4755  4765   80800   4765
# 2018-01-12  4800  4800  4730  4755   43200   4755
# 2018-01-15  4760  4815  4730  4765   42900   4765
# 2018-01-16  4765  4790  4740  4775   31300   4775
# 2018-01-17  4755  4775  4685  4710   69700   4710
# 2018-01-18  4750  4750  4675  4685   47200   4685
# 2018-01-19  4685  4705  4660  4680   42300   4680
# 2018-01-22  4675  4785  4675  4785   60400   4785
# 2018-01-23  4785  4860  4770  4790   48100   4790
# 2018-01-24  4815  4825  4700  4750   50400   4750
# 2018-01-25  4730  4770  4705  4740   31400   4740
# 2018-01-26  4735  4765  4715  4725   27300   4725
# 2018-01-29  4765  4790  4730  4760   35100   4760
# 2018-01-30  4775  4775  4670  4735   59700   4735
# ...

# %%
df_2018.index
# Out:
# DatetimeIndex(['2018-01-04', '2018-01-05', '2018-01-09', '2018-01-10',
#                '2018-01-11', '2018-01-12', '2018-01-15', '2018-01-16',
#                '2018-01-17', '2018-01-18',
#                ...
#                '2018-12-14', '2018-12-17', '2018-12-18', '2018-12-19',
#                '2018-12-20', '2018-12-21', '2018-12-25', '2018-12-26',
#                '2018-12-27', '2018-12-28'],
#               dtype='datetime64[ns]', name='日付', length=245, freq=None)

# %%
df=pd.concat([df1, df2],axis=1)
df
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-49b41c88af08> in <module>()
# ----> 1 df=pd.concat([df1, df2],axis=1)
#       2 df
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     227                        verify_integrity=verify_integrity,
#     228                        copy=copy, sort=sort)
# --> 229     return op.get_result()
#     230
# ...
